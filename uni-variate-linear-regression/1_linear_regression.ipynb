# %% [markdown]
# <h2>Machine Learning: Linear Regression With One Variable</h2>

# %% [markdown]
# <h3 style="color:purple">Sample problem of predicting home price in monroe, new jersey (USA)</h3>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.show()

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
# reg.fit(new_df['area'],price)
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %% [markdown]
# **(1) Predict price of a home with area = 3300 sqr ft**

# %%
reg.predict([[3300]])
# Out:
# c:\Users\Abdul Ahad\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628813.88621022])

# %%
reg.coef_
# Out:
# array([167.30954677])

# %%
reg.intercept_
# Out:
# 76692.3818707813

# %% [markdown]
# **Y = m * X + b (m is coefficient and b is intercept)**

# %%
3300*135.78767123 + 180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# **(1) Predict price of a home with area = 5000 sqr ft**

# %%
reg.predict([[5000]])
# Out:
# c:\Users\Abdul Ahad\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([913240.11571842])

# %% [markdown]
# <h3 style="color:purple">Generate CSV file with list of home price predictions</h3>

# %%
area_df = pd.read_csv("areas.csv")
area_df.head(3)
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200

# %%
p = reg.predict(area_df)
p
# Out:
# array([511697.20347155, 578621.02217936, 612082.93153327, 679006.75024108,
#        745930.56894889, 762661.52362584])

# %%
area_df['prices']=p
area_df
# Out:
#    area         prices
# 0  2600  511697.203472
# 1  3000  578621.022179
# 2  3200  612082.931533
# 3  3600  679006.750241
# 4  4000  745930.568949
# 5  4100  762661.523626

# %%
area_df.to_csv("prediction.csv")

# %% [markdown]
# <h3>Exercise</h3>

# %% [markdown]
# <p >Predict canada's per capita income in year 2020. Using this build a regression model and predict the per capita income fo canadian citizens in year 2020</p>

# %%
df1 = pd.read_csv('canada_per_capita_income_exercise.csv')
df1
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.scatter(df1['year'], df1['per capita income (US$)'], color= 'red', marker='+')
plt.show()

# %%
X = df1.drop('per capita income (US$)', axis=1)
X
# Out:
# pandas.core.frame.DataFrame

# %%
Y= df1['per capita income (US$)']
Y
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# c:\Users\Abdul Ahad\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
